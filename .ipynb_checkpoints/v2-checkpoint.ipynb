# %%
from tvb.simulator.lab import *
import tvb.interfaces.command.demos as demo
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as st
import itertools
from sklearn import manifold
from sklearn.preprocessing import StandardScaler
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/mb/.virtualenvs/tvb/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['mat']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
mat = scipy.io.loadmat('empirical_fMRI/empirical_fMRI.mat')
eeg = scipy.io.loadmat('HRF_200Hz.mat')

# %%
#eeg.keys()

# %%
data = np.asarray([x[0][0] for x in mat['fMRI'].T])
scaler = StandardScaler()
data = np.asarray([scaler.fit_transform(subj) for subj in data])

# %%
def get_cofluct(subj):
    rslt = np.empty((subj.shape[1], subj.shape[1], subj.shape[0]))
    for i, j in itertools.combinations_with_replacement(list(range(subj.shape[1])), r=2):
        if i != j:
            rslt[i,j] = subj[:,i]*subj[:,j]
            rslt[i,j] = rslt[i,j]#/np.mean(rslt[i,j])
            #rslt[j,i] = rslt[i,j]
    return rslt

# %%
def get_fc(subj):
    rslt = np.empty((subj.shape[1], subj.shape[1]))
    for i, j in itertools.combinations_with_replacement(list(range(subj.shape[1])), r=2):
        if i != j:
            rslt[i,j] = np.sum(subj[:,i]*subj[:,j])/660
            rslt[i,j] = rslt[i,j]#/np.mean(rslt[i,j])
            #rslt[j,i] = rslt[i,j]
    return rslt

# %%
def top_bottom_fcs(X):
    (p5, p95) = np.percentile(np.linalg.norm(X, axis=0), [5, 95])
    bottom = np.where(np.linalg.norm(X, axis=0) <= p5, X, 0).reshape((68,68,661))
    top = np.where(np.linalg.norm(X, axis=0) > p95, X, 0).reshape((68,68,661))
    top_fc = np.mean(top, axis=2)
    bot_fc = np.mean(bottom, axis=2)
    return (top_fc, bot_fc)

# %%
corr_tops = []
corr_bots = []
for subj in data:
    cofluct = get_cofluct(subj)
    X_fc = get_fc(subj)
    X = cofluct.reshape((cofluct.shape[0]**2, cofluct.shape[2]))
    (top_fc, bot_fc) = top_bottom_fcs(X)
    corr_tops.append(np.corrcoef(np.triu(X_fc).ravel(), np.triu(top_fc).ravel())[0,1])
    corr_bots.append(np.corrcoef(np.triu(X_fc).ravel(), np.triu(bot_fc).ravel())[0,1])
#(top_fc, bot_fc) = top_bottom_fcs(X2)
#np.corrcoef(np.triu(X_fc).ravel(), np.triu(top_fc).ravel())[0,1]

# %%
dat = []
for i, j in zip(corr_bots, corr_tops):
    dat.append([i,j])
df = pd.DataFrame(dat, columns = ['bottom', 'top'])
df
# Out:
#       bottom       top
# 0   0.391137  0.974211
# 1   0.426393  0.878988
# 2   0.360593  0.934048
# 3   0.407190  0.922572
# 4   0.467206  0.967267
# 5   0.316437  0.950726
# 6   0.447238  0.858866
# 7   0.388917  0.912710
# 8   0.381903  0.943274
# 9   0.400527  0.968186
# 10  0.348432  0.904578
# 11  0.489601  0.869714
# 12  0.381501  0.919847
# 13  0.356040  0.963826
# 14  0.346249  0.972231

# %%
df.boxplot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
#X = get_cofluct(data[1])
#X_fc = get_fc(data[1])
#plt.imshow(np.mean(X, axis=2))
#X2 = X.reshape((X.shape[0]**2, X.shape[2]))
#X2.shape
#plt.figure()
#plt.hist(np.linalg.norm(X2, axis=0), histtype='step', bins=200)
#plt.show()
